# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split
import unicodedata
import re
import numpy as np
import os
import io
import time
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
path_to_file = '/content/drive/My Drive/Colab Notebooks/dataset_1.txt'

# %%
path_to_file
# Out:
# '/content/drive/My Drive/Colab Notebooks/dataset_1.txt'

# %%
# Converts the unicode file to ascii
def unicode_to_ascii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')


def preprocess_sentence(w):
  w = unicode_to_ascii(w.lower().strip())

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,¿])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
en_sentence = u"May I borrow this book?"
sp_sentence = u"¿Puedo tomar prestado este libro?"
print(preprocess_sentence(en_sentence))
print(preprocess_sentence(sp_sentence).encode('utf-8'))
# Out:
# <start> may i borrow this book ? <end>
# b'<start> \xc2\xbf puedo tomar prestado este libro ? <end>'

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENGLISH, SPANISH]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('|')]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, sp = create_dataset(path_to_file, None)
print(en[-1])
print(sp[-1])
# Out:
# <start> which department does he work in ? <end>
# <start> em qual departamento ele trabalha ? <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  inp_lang, targ_lang  = create_dataset(path, num_examples)  #[ENGLISH, SPANISH]

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### Limit the size of the dataset to experiment faster (optional)
#
# Training on the complete dataset of >100,000 sentences will take a long time. To train faster, we can limit the size of the dataset to 30,000 sentences (of course, translation quality degrades with less data):

# %%
# Try experimenting with the size of that dataset
num_examples = 500000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.1)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 3600 3600 400 400

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 12 ----> my
# 225 ----> husband
# 9 ----> is
# 940 ----> making
# 104 ----> coffee
# 79 ----> now
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 26 ----> meu
# 192 ----> marido
# 14 ----> esta
# 327 ----> fazendo
# 72 ----> cafe
# 82 ----> agora
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# ### Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 16
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 64
units = 256
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([16, 17]), TensorShape([16, 18]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (16, 17, 256)
# Encoder Hidden state shape: (batch size, units) (16, 256)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # query hidden state shape == (batch_size, hidden size)
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    # values shape == (batch_size, max_len, hidden size)
    # we are doing this to broadcast addition along the time axis to calculate the score
    query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (16, 256)
# Attention weights shape: (batch_size, sequence_length, 1) (16, 17, 1)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output shape == (batch_size, max_length, hidden_size)
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (16, 3145)

# %% [markdown]
# ## Define the optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoints (Object-based saving)

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %% [markdown]
# ## Training
#
# 1. Pass the *input* through the *encoder* which return *encoder output* and the *encoder hidden state*.
# 2. The encoder output, encoder hidden state and the decoder input (which is the *start token*) is passed to the decoder.
# 3. The decoder returns the *predictions* and the *decoder hidden state*.
# 4. The decoder hidden state is then passed back into the model and the predictions are used to calculate the loss.
# 5. Use *teacher forcing* to decide the next input to the decoder.
# 6. *Teacher forcing* is the technique where the *target word* is passed as the *next input* to the decoder.
# 7. The final step is to calculate the gradients and apply it to the optimizer and backpropagate.

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 3.7192
# Epoch 1 Batch 100 Loss 2.7320
# Epoch 1 Batch 200 Loss 2.3536
# Epoch 1 Loss 2.5249
# Time taken for 1 epoch 25.67723298072815 sec
#
# Epoch 2 Batch 0 Loss 2.0870
# Epoch 2 Batch 100 Loss 2.4934
# Epoch 2 Batch 200 Loss 2.1218
# Epoch 2 Loss 2.2114
# Time taken for 1 epoch 7.264027833938599 sec
#
# Epoch 3 Batch 0 Loss 2.0212
# Epoch 3 Batch 100 Loss 2.1769
# Epoch 3 Batch 200 Loss 2.1195
# Epoch 3 Loss 2.0944
# Time taken for 1 epoch 7.016449689865112 sec
#
# Epoch 4 Batch 0 Loss 1.8471
# Epoch 4 Batch 100 Loss 1.9781
# Epoch 4 Batch 200 Loss 1.9132
# Epoch 4 Loss 1.9880
# Time taken for 1 epoch 7.15362811088562 sec
#
# Epoch 5 Batch 0 Loss 2.0501
# Epoch 5 Batch 100 Loss 1.8213
# Epoch 5 Batch 200 Loss 1.6918
# Epoch 5 Loss 1.8604
# Time taken for 1 epoch 6.997329473495483 sec
#
# Epoch 6 Batch 0 Loss 1.8124
# Epoch 6 Batch 100 Loss 1.7720
# Epoch 6 Batch 200 Loss 1.4822
# Epoch 6 Loss 1.7301
# Time taken for 1 epoch 7.147558927536011 sec
#
# Epoch 7 Batch 0 Loss 1.7477
# Epoch 7 Batch 100 Loss 1.6697
# Epoch 7 Batch 200 Loss 1.5202
# Epoch 7 Loss 1.6137
# Time taken for 1 epoch 7.0275304317474365 sec
#
# Epoch 8 Batch 0 Loss 1.2797
# Epoch 8 Batch 100 Loss 1.5807
# Epoch 8 Batch 200 Loss 1.6784
# Epoch 8 Loss 1.5072
# Time taken for 1 epoch 7.106980800628662 sec
#
# Epoch 9 Batch 0 Loss 1.5092
# Epoch 9 Batch 100 Loss 1.5087
# Epoch 9 Batch 200 Loss 1.3182
# Epoch 9 Loss 1.4014
# Time taken for 1 epoch 7.0865137577056885 sec
#
# Epoch 10 Batch 0 Loss 1.1543
# Epoch 10 Batch 100 Loss 1.4089
# Epoch 10 Batch 200 Loss 1.2656
# Epoch 10 Loss 1.2909
# Time taken for 1 epoch 7.095934152603149 sec
#
# Epoch 11 Batch 0 Loss 1.0402
# Epoch 11 Batch 100 Loss 1.2554
# Epoch 11 Batch 200 Loss 1.1544
# Epoch 11 Loss 1.1850
# Time taken for 1 epoch 7.060417890548706 sec
#
# Epoch 12 Batch 0 Loss 0.9050
# Epoch 12 Batch 100 Loss 1.1519
# Epoch 12 Batch 200 Loss 0.9693
# Epoch 12 Loss 1.0755
# Time taken for 1 epoch 7.280014991760254 sec
#
# Epoch 13 Batch 0 Loss 0.7435
# Epoch 13 Batch 100 Loss 0.9274
# Epoch 13 Batch 200 Loss 1.0803
# Epoch 13 Loss 0.9759
# Time taken for 1 epoch 7.107202053070068 sec
#
# Epoch 14 Batch 0 Loss 0.9093
# Epoch 14 Batch 100 Loss 0.8952
# Epoch 14 Batch 200 Loss 0.9671
# Epoch 14 Loss 0.8800
# Time taken for 1 epoch 7.0701658725738525 sec
#
# Epoch 15 Batch 0 Loss 0.6918
# Epoch 15 Batch 100 Loss 0.8344
# Epoch 15 Batch 200 Loss 0.7236
# Epoch 15 Loss 0.7937
# Time taken for 1 epoch 6.969620704650879 sec
#
# Epoch 16 Batch 0 Loss 0.8462
# Epoch 16 Batch 100 Loss 0.7333
# Epoch 16 Batch 200 Loss 0.8700
# Epoch 16 Loss 0.7084
# Time taken for 1 epoch 7.025548934936523 sec
#
# Epoch 17 Batch 0 Loss 0.5470
# Epoch 17 Batch 100 Loss 0.5960
# Epoch 17 Batch 200 Loss 0.5626
# Epoch 17 Loss 0.6317
# Time taken for 1 epoch 7.108509063720703 sec
#
# Epoch 18 Batch 0 Loss 0.5726
# Epoch 18 Batch 100 Loss 0.4533
# Epoch 18 Batch 200 Loss 0.6838
# Epoch 18 Loss 0.5591
# Time taken for 1 epoch 7.132920265197754 sec
#
# Epoch 19 Batch 0 Loss 0.4236
# Epoch 19 Batch 100 Loss 0.5077
# Epoch 19 Batch 200 Loss 0.4441
# Epoch 19 Loss 0.5007
# Time taken for 1 epoch 7.00316047668457 sec
#
# Epoch 20 Batch 0 Loss 0.3588
# Epoch 20 Batch 100 Loss 0.4357
# Epoch 20 Batch 200 Loss 0.4436
# Epoch 20 Loss 0.4395
# Time taken for 1 epoch 6.951914072036743 sec
#
# Epoch 21 Batch 0 Loss 0.4326
# Epoch 21 Batch 100 Loss 0.3864
# Epoch 21 Batch 200 Loss 0.3733
# Epoch 21 Loss 0.3898
# Time taken for 1 epoch 7.148882150650024 sec
#
# Epoch 22 Batch 0 Loss 0.2190
# Epoch 22 Batch 100 Loss 0.2388
# Epoch 22 Batch 200 Loss 0.3615
# Epoch 22 Loss 0.3375
# Time taken for 1 epoch 7.163095712661743 sec
#
# Epoch 23 Batch 0 Loss 0.2022
# Epoch 23 Batch 100 Loss 0.2603
# Epoch 23 Batch 200 Loss 0.2818
# Epoch 23 Loss 0.3036
# Time taken for 1 epoch 7.083953619003296 sec
#
# Epoch 24 Batch 0 Loss 0.2205
# Epoch 24 Batch 100 Loss 0.2111
# Epoch 24 Batch 200 Loss 0.2691
# Epoch 24 Loss 0.2561
# Time taken for 1 epoch 7.047868013381958 sec
#
# Epoch 25 Batch 0 Loss 0.3049
# Epoch 25 Batch 100 Loss 0.2178
# Epoch 25 Batch 200 Loss 0.2773
# Epoch 25 Loss 0.2232
# Time taken for 1 epoch 6.831569671630859 sec
#
# Epoch 26 Batch 0 Loss 0.1776
# Epoch 26 Batch 100 Loss 0.1950
# Epoch 26 Batch 200 Loss 0.2579
# Epoch 26 Loss 0.1906
# Time taken for 1 epoch 6.932109355926514 sec
#
# Epoch 27 Batch 0 Loss 0.1564
# Epoch 27 Batch 100 Loss 0.1809
# Epoch 27 Batch 200 Loss 0.1679
# Epoch 27 Loss 0.1681
# Time taken for 1 epoch 6.982638120651245 sec
#
# Epoch 28 Batch 0 Loss 0.1094
# Epoch 28 Batch 100 Loss 0.1178
# Epoch 28 Batch 200 Loss 0.1091
# Epoch 28 Loss 0.1472
# Time taken for 1 epoch 7.077224016189575 sec
#
# Epoch 29 Batch 0 Loss 0.1177
# Epoch 29 Batch 100 Loss 0.1382
# Epoch 29 Batch 200 Loss 0.2115
# Epoch 29 Loss 0.1250
# Time taken for 1 epoch 6.892417907714844 sec
#
# Epoch 30 Batch 0 Loss 0.0658
# Epoch 30 Batch 100 Loss 0.1013
# Epoch 30 Batch 200 Loss 0.0846
# Epoch 30 Loss 0.1075
# Time taken for 1 epoch 7.018494129180908 sec
#
# Epoch 31 Batch 0 Loss 0.0810
# Epoch 31 Batch 100 Loss 0.1150
# Epoch 31 Batch 200 Loss 0.1085
# Epoch 31 Loss 0.0978
# Time taken for 1 epoch 7.086007118225098 sec
#
# Epoch 32 Batch 0 Loss 0.1353
# Epoch 32 Batch 100 Loss 0.0702
# Epoch 32 Batch 200 Loss 0.1092
# Epoch 32 Loss 0.0885
# Time taken for 1 epoch 7.152574777603149 sec
#
# Epoch 33 Batch 0 Loss 0.0791
# Epoch 33 Batch 100 Loss 0.0981
# Epoch 33 Batch 200 Loss 0.0574
# Epoch 33 Loss 0.0801
# Time taken for 1 epoch 6.952158212661743 sec
#
# Epoch 34 Batch 0 Loss 0.0570
# Epoch 34 Batch 100 Loss 0.0694
# Epoch 34 Batch 200 Loss 0.0848
# Epoch 34 Loss 0.0644
# Time taken for 1 epoch 7.085500001907349 sec
#
# Epoch 35 Batch 0 Loss 0.0587
# Epoch 35 Batch 100 Loss 0.0413
# Epoch 35 Batch 200 Loss 0.0440
# Epoch 35 Loss 0.0549
# Time taken for 1 epoch 7.281010627746582 sec
#
# Epoch 36 Batch 0 Loss 0.0688
# Epoch 36 Batch 100 Loss 0.0402
# Epoch 36 Batch 200 Loss 0.0532
# Epoch 36 Loss 0.0451
# Time taken for 1 epoch 7.222529649734497 sec
#
# Epoch 37 Batch 0 Loss 0.0303
# Epoch 37 Batch 100 Loss 0.0520
# Epoch 37 Batch 200 Loss 0.0499
# Epoch 37 Loss 0.0382
# Time taken for 1 epoch 7.057588577270508 sec
#
# Epoch 38 Batch 0 Loss 0.0264
# Epoch 38 Batch 100 Loss 0.1443
# Epoch 38 Batch 200 Loss 0.0577
# Epoch 38 Loss 0.0746
# Time taken for 1 epoch 7.055208683013916 sec
#
# Epoch 39 Batch 0 Loss 0.0883
# Epoch 39 Batch 100 Loss 0.0842
# Epoch 39 Batch 200 Loss 0.0674
# Epoch 39 Loss 0.0914
# Time taken for 1 epoch 6.934586763381958 sec
#
# Epoch 40 Batch 0 Loss 0.0539
# Epoch 40 Batch 100 Loss 0.0461
# Epoch 40 Batch 200 Loss 0.0436
# Epoch 40 Loss 0.0481
# Time taken for 1 epoch 7.077943325042725 sec
#
# Epoch 41 Batch 0 Loss 0.0368
# Epoch 41 Batch 100 Loss 0.0210
# Epoch 41 Batch 200 Loss 0.0405
# Epoch 41 Loss 0.0319
# Time taken for 1 epoch 7.035800933837891 sec
#
# Epoch 42 Batch 0 Loss 0.0135
# Epoch 42 Batch 100 Loss 0.0225
# Epoch 42 Batch 200 Loss 0.0263
# Epoch 42 Loss 0.0235
# Time taken for 1 epoch 7.0023534297943115 sec
#
# Epoch 43 Batch 0 Loss 0.0161
# Epoch 43 Batch 100 Loss 0.0161
# Epoch 43 Batch 200 Loss 0.0172
# Epoch 43 Loss 0.0175
# Time taken for 1 epoch 6.9166810512542725 sec
#
# Epoch 44 Batch 0 Loss 0.0196
# Epoch 44 Batch 100 Loss 0.0210
# Epoch 44 Batch 200 Loss 0.0178
# Epoch 44 Loss 0.0142
# Time taken for 1 epoch 6.895087242126465 sec
#
# Epoch 45 Batch 0 Loss 0.0146
# Epoch 45 Batch 100 Loss 0.0095
# Epoch 45 Batch 200 Loss 0.0095
# Epoch 45 Loss 0.0122
# Time taken for 1 epoch 7.0209269523620605 sec
#
# Epoch 46 Batch 0 Loss 0.0127
# Epoch 46 Batch 100 Loss 0.0086
# Epoch 46 Batch 200 Loss 0.0096
# Epoch 46 Loss 0.0111
# Time taken for 1 epoch 7.130356550216675 sec
#
# Epoch 47 Batch 0 Loss 0.0078
# Epoch 47 Batch 100 Loss 0.0068
# Epoch 47 Batch 200 Loss 0.0055
# Epoch 47 Loss 0.0098
# Time taken for 1 epoch 7.038559913635254 sec
#
# Epoch 48 Batch 0 Loss 0.0061
# Epoch 48 Batch 100 Loss 0.0145
# Epoch 48 Batch 200 Loss 0.0068
# Epoch 48 Loss 0.0092
# Time taken for 1 epoch 6.890859842300415 sec
#
# Epoch 49 Batch 0 Loss 0.0071
# Epoch 49 Batch 100 Loss 0.0194
# Epoch 49 Batch 200 Loss 0.0177
# Epoch 49 Loss 0.0091
# Time taken for 1 epoch 7.169203281402588 sec
#
# Epoch 50 Batch 0 Loss 0.0054
# Epoch 50 Batch 100 Loss 0.0076
# Epoch 50 Batch 200 Loss 0.0060
# Epoch 50 Loss 0.0096
# Time taken for 1 epoch 7.248925685882568 sec

# %% [markdown]
# ## Translate
#
# * The evaluate function is similar to the training loop, except we don't use *teacher forcing* here. The input to the decoder at each time step is its previous predictions along with the hidden state and the encoder output.
# * Stop predicting when the model predicts the *end token*.
# * And store the *attention weights for every time step*.
#
# Note: The encoder output is calculated only once for one input.

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_out, enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)

    # storing the attention weights to plot later on
    attention_weights = tf.reshape(attention_weights, (-1, ))
    attention_plot[t] = attention_weights.numpy()

    predicted_id = tf.argmax(predictions[0]).numpy()

    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence, attention_plot

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence, attention_plot

# %%
# function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
  fig = plt.figure(figsize=(10,10))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
def translate(sentence):
  result, sentence, attention_plot = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

  attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %% [markdown]
# ## Restore the latest checkpoint and test

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate(u'I want to eat')
translate(u'I love tea')
translate(u'I want to drink water')
translate(u'Can we play a game')
# Out:
# Input: <start> i want to eat <end>
# Predicted translation: eu quero comer . <end>
# Input: <start> i love tea <end>
# Predicted translation: eu amo tres . <end>
# Input: <start> i want to drink water <end>
# Predicted translation: eu quero beber agua . <end>
# Input: <start> can we play a game <end>
# Predicted translation: eu nos visitar um taxi . <end>

# %%
# !zip -r /content/training_checkpoints_dataset_1.zip /content/training_checkpoints
# Out:
#   adding: content/training_checkpoints/ (stored 0%)
#   adding: content/training_checkpoints/ckpt-3.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-9.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-16.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-19.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-14.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-25.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-23.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-10.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-2.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-2.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/checkpoint (deflated 38%)
#   adding: content/training_checkpoints/ckpt-15.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-18.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-18.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-14.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-9.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-7.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-22.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-6.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-8.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-21.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-11.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-3.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-4.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-16.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-5.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-19.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-24.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-8.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-21.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-10.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-12.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-22.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-12.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-24.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-23.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-6.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-17.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-13.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-17.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-4.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-1.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-1.data-00000-of-00001 (deflated 14%)
#   adding: content/training_checkpoints/ckpt-20.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-15.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-7.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-11.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-20.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-5.index (deflated 69%)
#   adding: content/training_checkpoints/ckpt-13.data-00000-of-00001 (deflated 13%)
#   adding: content/training_checkpoints/ckpt-25.index (deflated 69%)

# %%
print('hi d5555 new')
# Out:
# hi d5555 new

# %%
from google.colab import files
files.download('/content/training_checkpoints_dataset_1.zip')
